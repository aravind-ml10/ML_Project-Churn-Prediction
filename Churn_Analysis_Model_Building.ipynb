# %%
# Importing necessary libraries

import pandas as pd
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.tree import DecisionTreeClassifier


pd.pandas.set_option('display.max_columns',None)

# %%
# Reading dataset
df=pd.read_csv('/content/tele_churn.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  SeniorCitizen  MonthlyCharges  TotalCharges  Churn  \
# 0           0              0           29.85         29.85      0
# 1           1              0           56.95       1889.50      0
# 2           2              0           53.85        108.15      1
# 3           3              0           42.30       1840.75      0
# 4           4              0           70.70        151.65      1
#
#    gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  \
# 0              1            0           0            1              1
# 1              0            1           1            0              1
# 2              0            1           1            0              1
# 3              0            1           1            0              1
# 4              1            0           1            0              1
#
#    Dependents_Yes  PhoneService_No  PhoneService_Yes  MultipleLines_No  \
# 0               0                1                 0                 0
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0  SeniorCitizen  MonthlyCharges  TotalCharges  Churn  \
# 7027        7038              0           84.80       1990.50      0
# 7028        7039              0          103.20       7362.90      0
# 7029        7040              0           29.60        346.45      0
# 7030        7041              1           74.40        306.60      1
# 7031        7042              0          105.65       6844.50      0
#
#       gender_Female  gender_Male  Partner_No  Partner_Yes  Dependents_No  \
# 7027              0            1           0            1              0
# 7028              1            0           0            1              0
# 7029              1            0           0            1              0
# 7030              0            1           0            1              1
# 7031              0            1           1            0              1
#
#       Dependents_Yes  PhoneService_No  PhoneService_Yes  MultipleLines_No  \
# ...

# %%
df.shape
# Out:
# (7032, 52)

# %%
# Droping unnecessary columns
df.drop(columns=['Unnamed: 0'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (7032, 51)

# %%
# Input and Output data seperation

x=df.drop('Churn',axis=1)
y=df['Churn']

# %%
x
# Out:
#       SeniorCitizen  MonthlyCharges  TotalCharges  gender_Female  gender_Male  \
# 0                 0           29.85         29.85              1            0
# 1                 0           56.95       1889.50              0            1
# 2                 0           53.85        108.15              0            1
# 3                 0           42.30       1840.75              0            1
# 4                 0           70.70        151.65              1            0
# ...             ...             ...           ...            ...          ...
# 7027              0           84.80       1990.50              0            1
# 7028              0          103.20       7362.90              1            0
# 7029              0           29.60        346.45              1            0
# 7030              1           74.40        306.60              0            1
# 7031              0          105.65       6844.50              0            1
#
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7027    0
# 7028    0
# 7029    0
# 7030    1
# 7031    0
# Name: Churn, Length: 7032, dtype: int64

# %%
# Training and Testing data seperation

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20)

# %%
# Normalising
scalar=MinMaxScaler()
x_train= scalar.fit_transform(x_train)
x_test= scalar.transform(x_test)

# %% [markdown]
# **Decision Tree Classifier**

# %%
model_dt=DecisionTreeClassifier(criterion = "gini",random_state = 100,max_depth=6, min_samples_leaf=8)
model_dt.fit(x_train,y_train)
y_pred=model_dt.predict(x_test)
y_pred
# Out:
# array([0, 0, 1, ..., 0, 0, 1])

# %%
# Confusion Matrix 
cm= confusion_matrix(y_test,y_pred)
cmd= ConfusionMatrixDisplay(cm,display_labels=[0,1])
cmd.plot()

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,y_pred)
print('Accuracy of Decision tree model is {}'.format(score))
# Out:
# Accuracy of Decision tree model is 0.7818052594171997

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.89      0.86      1022
#            1       0.63      0.50      0.56       385
#
#     accuracy                           0.78      1407
#    macro avg       0.73      0.70      0.71      1407
# weighted avg       0.77      0.78      0.77      1407

# %% [markdown]
# This model has greater than **75 percentage accuracy**. Therefore it is a good model.
